# %%
# Basic Imports 
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Keras Imports 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

# sklearn imports
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# Data Loading and Preprocessing

# %%
data_dir = '/kaggle/input/face-expression-recognition-dataset/images'
train_dir = os.path.join(data_dir, 'train')
validation_dir = os.path.join(data_dir, 'validation')

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,  
    rotation_range=20,
    zoom_range=0.2, 
    horizontal_flip=True
)
validation_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode='categorical',
    color_mode='grayscale'
)
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode='categorical',
    color_mode='grayscale'
)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# EDA

# %%
class_names = list(train_generator.class_indices.keys())

images, labels = next(train_generator)
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].reshape(48, 48), cmap='gray')
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# CNN Model Archietecture

# %%
model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(256, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(7, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 46, 46, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 46, 46, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 21, 21, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,474,759 (9.44 MB)
#  Trainable params: 2,472,839 (9.43 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %% [markdown]
# Model Training

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)

# Model Training
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 57s 108ms/step - accuracy: 0.2359 - loss: 2.4148 - val_accuracy: 0.2830 - val_loss: 1.8413 - learning_rate: 0.0010
# Epoch 2/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 43s 96ms/step - accuracy: 0.3733 - loss: 1.6714 - val_accuracy: 0.4612 - val_loss: 1.4246 - learning_rate: 0.0010
# Epoch 3/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 44s 97ms/step - accuracy: 0.4352 - loss: 1.4769 - val_accuracy: 0.4376 - val_loss: 1.4533 - learning_rate: 0.0010
# Epoch 4/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 43s 96ms/step - accuracy: 0.4639 - loss: 1.4011 - val_accuracy: 0.4959 - val_loss: 1.3109 - learning_rate: 0.0010
# Epoch 5/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 44s 98ms/step - accuracy: 0.4783 - loss: 1.3639 - val_accuracy: 0.5344 - val_loss: 1.2263 - learning_rate: 0.0010
# Epoch 6/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 43s 95ms/step - accuracy: 0.4930 - loss: 1.3197 - val_accuracy: 0.5146 - val_loss: 1.2713 - learning_rate: 0.0010
# Epoch 7/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.5079 - loss: 1.2976 - val_accuracy: 0.5434 - val_loss: 1.2091 - learning_rate: 0.0010
# Epoch 8/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 85ms/step - accuracy: 0.5151 - loss: 1.2701 - val_accuracy: 0.5364 - val_loss: 1.2009 - learning_rate: 0.0010
# Epoch 9/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 84ms/step - accuracy: 0.5236 - loss: 1.2504 - val_accuracy: 0.5382 - val_loss: 1.1878 - learning_rate: 0.0010
# Epoch 10/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 84ms/step - accuracy: 0.5339 - loss: 1.2369 - val_accuracy: 0.5416 - val_loss: 1.2181 - learning_rate: 0.0010
# Epoch 11/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 85ms/step - accuracy: 0.5354 - loss: 1.2330 - val_accuracy: 0.5548 - val_loss: 1.1577 - learning_rate: 0.0010
# Epoch 12/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 36s 80ms/step - accuracy: 0.5393 - loss: 1.2209 - val_accuracy: 0.5146 - val_loss: 1.3202 - learning_rate: 0.0010
# Epoch 13/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 86ms/step - accuracy: 0.5350 - loss: 1.2181 - val_accuracy: 0.5243 - val_loss: 1.2574 - learning_rate: 0.0010
# Epoch 14/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 37s 83ms/step - accuracy: 0.5459 - loss: 1.1826 - val_accuracy: 0.5804 - val_loss: 1.1114 - learning_rate: 0.0010
# Epoch 15/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 84ms/step - accuracy: 0.5486 - loss: 1.1830 - val_accuracy: 0.5078 - val_loss: 1.3310 - learning_rate: 0.0010
# Epoch 16/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.5543 - loss: 1.1731 - val_accuracy: 0.5834 - val_loss: 1.1209 - learning_rate: 0.0010
# Epoch 17/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5583 - loss: 1.1669
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 37s 81ms/step - accuracy: 0.5582 - loss: 1.1669 - val_accuracy: 0.5006 - val_loss: 1.3446 - learning_rate: 0.0010
# Epoch 18/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.5726 - loss: 1.1306 - val_accuracy: 0.6102 - val_loss: 1.0251 - learning_rate: 2.0000e-04
# Epoch 19/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 84ms/step - accuracy: 0.5805 - loss: 1.1071 - val_accuracy: 0.6128 - val_loss: 1.0252 - learning_rate: 2.0000e-04
# Epoch 20/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 84ms/step - accuracy: 0.5887 - loss: 1.0963 - val_accuracy: 0.6175 - val_loss: 1.0178 - learning_rate: 2.0000e-04
# Epoch 21/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 37s 83ms/step - accuracy: 0.5904 - loss: 1.0774 - val_accuracy: 0.6148 - val_loss: 1.0250 - learning_rate: 2.0000e-04
# Epoch 22/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.5976 - loss: 1.0754 - val_accuracy: 0.6217 - val_loss: 1.0103 - learning_rate: 2.0000e-04
# Epoch 23/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 34s 76ms/step - accuracy: 0.5986 - loss: 1.0691 - val_accuracy: 0.6226 - val_loss: 1.0112 - learning_rate: 2.0000e-04
# Epoch 24/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.5950 - loss: 1.0721 - val_accuracy: 0.6267 - val_loss: 0.9956 - learning_rate: 2.0000e-04
# Epoch 25/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.6055 - loss: 1.0534 - val_accuracy: 0.6296 - val_loss: 0.9924 - learning_rate: 2.0000e-04
# Epoch 26/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 36s 80ms/step - accuracy: 0.5977 - loss: 1.0550 - val_accuracy: 0.6117 - val_loss: 1.0453 - learning_rate: 2.0000e-04
# Epoch 27/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 79ms/step - accuracy: 0.6105 - loss: 1.0435 - val_accuracy: 0.6260 - val_loss: 0.9992 - learning_rate: 2.0000e-04
# Epoch 28/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6029 - loss: 1.0491
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.6029 - loss: 1.0491 - val_accuracy: 0.6285 - val_loss: 0.9954 - learning_rate: 2.0000e-04
# Epoch 29/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 36s 80ms/step - accuracy: 0.6052 - loss: 1.0424 - val_accuracy: 0.6363 - val_loss: 0.9832 - learning_rate: 4.0000e-05
# Epoch 30/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.6108 - loss: 1.0385 - val_accuracy: 0.6254 - val_loss: 1.0057 - learning_rate: 4.0000e-05
# Epoch 31/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.6069 - loss: 1.0448 - val_accuracy: 0.6350 - val_loss: 0.9868 - learning_rate: 4.0000e-05
# Epoch 32/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6177 - loss: 1.0265
# Epoch 32: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 34s 76ms/step - accuracy: 0.6177 - loss: 1.0265 - val_accuracy: 0.6269 - val_loss: 0.9982 - learning_rate: 4.0000e-05
# Epoch 33/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 34s 76ms/step - accuracy: 0.6234 - loss: 1.0150 - val_accuracy: 0.6308 - val_loss: 0.9863 - learning_rate: 8.0000e-06
# Epoch 34/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.6112 - loss: 1.0283 - val_accuracy: 0.6337 - val_loss: 0.9812 - learning_rate: 8.0000e-06
# Epoch 35/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.6081 - loss: 1.0305 - val_accuracy: 0.6322 - val_loss: 0.9799 - learning_rate: 8.0000e-06
# Epoch 36/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.6144 - loss: 1.0250 - val_accuracy: 0.6313 - val_loss: 0.9841 - learning_rate: 8.0000e-06
# Epoch 37/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.6125 - loss: 1.0224 - val_accuracy: 0.6332 - val_loss: 0.9807 - learning_rate: 8.0000e-06
# Epoch 38/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6192 - loss: 1.0172
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 37s 82ms/step - accuracy: 0.6192 - loss: 1.0172 - val_accuracy: 0.6315 - val_loss: 0.9810 - learning_rate: 8.0000e-06
# Epoch 39/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 36s 80ms/step - accuracy: 0.6143 - loss: 1.0188 - val_accuracy: 0.6308 - val_loss: 0.9802 - learning_rate: 1.6000e-06
# Epoch 40/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.6123 - loss: 1.0240 - val_accuracy: 0.6325 - val_loss: 0.9790 - learning_rate: 1.6000e-06
# Epoch 41/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 84ms/step - accuracy: 0.6114 - loss: 1.0331 - val_accuracy: 0.6326 - val_loss: 0.9770 - learning_rate: 1.6000e-06
# Epoch 42/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.6112 - loss: 1.0344 - val_accuracy: 0.6335 - val_loss: 0.9799 - learning_rate: 1.6000e-06
# Epoch 43/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.6189 - loss: 1.0332 - val_accuracy: 0.6319 - val_loss: 0.9803 - learning_rate: 1.6000e-06
# Epoch 44/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6193 - loss: 1.0221
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-06.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 42s 94ms/step - accuracy: 0.6193 - loss: 1.0221 - val_accuracy: 0.6311 - val_loss: 0.9831 - learning_rate: 1.6000e-06
# Epoch 45/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - accuracy: 0.6161 - loss: 1.0259 - val_accuracy: 0.6322 - val_loss: 0.9828 - learning_rate: 1.0000e-06
# Epoch 46/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 42s 92ms/step - accuracy: 0.6150 - loss: 1.0160 - val_accuracy: 0.6315 - val_loss: 0.9818 - learning_rate: 1.0000e-06

# %% [markdown]
# Evaluation

# %%
val_images, val_labels = next(validation_generator)
predictions = model.predict(val_images)
y_true = np.argmax(val_labels, axis=1)
y_pred = np.argmax(predictions, axis=1)

print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
#               precision    recall  f1-score   support
#
#        angry       0.50      0.27      0.35        11
#      disgust       1.00      0.20      0.33         5
#         fear       1.00      0.43      0.60         7
#        happy       0.89      1.00      0.94        16
#      neutral       0.46      0.60      0.52        10
#          sad       0.50      0.82      0.62        11
#     surprise       0.80      1.00      0.89         4
#
#     accuracy                           0.66        64
#    macro avg       0.74      0.62      0.61        64
# weighted avg       0.70      0.66      0.63        64

# %% [markdown]
# Detection System

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import numpy as np

def detect_emotion(image_path):
    img = image.load_img(image_path, target_size=(48, 48), color_mode='grayscale')
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = model.predict(img_array)
    predicted_index = np.argmax(prediction)
    predicted_class = class_names[predicted_index]
    confidence = round(prediction[0][predicted_index] * 100, 2)  # Confidence in %

    # Display the image with the predicted label and confidence
    plt.imshow(img, cmap='gray')
    plt.title(f'Predicted Emotion: {predicted_class} ({confidence}%)')
    plt.axis('off')
    plt.show()

    return predicted_class, confidence

# Example Detection
predicted_emotion, confidence = detect_emotion('/kaggle/input/face-expression-recognition-dataset/images/train/surprise/10011.jpg')
print(f"Emotion: {predicted_emotion}, Confidence: {confidence}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 652ms/step
# Emotion: surprise, Confidence: 88.67%

# %%
# Example Detection
print(detect_emotion('/kaggle/input/face-expression-recognition-dataset/images/train/happy/10005.jpg'))
print(detect_emotion('/kaggle/input/face-expression-recognition-dataset/images/train/angry/10207.jpg'))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ('happy', 99.33)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ('angry', 96.6)

# %%
print(detect_emotion('/kaggle/input/face-expression-recognition-dataset/images/validation/neutral/10033.jpg'))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ('neutral', 80.35)

# %%
print(detect_emotion('/kaggle/input/face-expression-recognition-dataset/images/validation/sad/1003.jpg'))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ('sad', 42.29)

# %%
print(detect_emotion('/kaggle/input/face-expression-recognition-dataset/images/validation/disgust/10435.jpg'))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ('disgust', 70.25)

# %%
model.save('facialemotion_detection_model.h5')

# %%
class_names
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
